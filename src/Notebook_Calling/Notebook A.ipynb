# %%
# Notebook A

print("Notebook A started")

# Call Notebook B
result_from_b = dbutils.notebook.run("/Workspace/Users/jayadheep356@gmail.com/DATABRICKS/src/Notebook_Calling/Notebook B", 60)

print("Result received from Notebook B:", result_from_b)

print("Notebook A completed")
