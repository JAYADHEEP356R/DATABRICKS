# %%
# Notebook B

print("Notebook B started")

# Call Notebook C
result_from_c = dbutils.notebook.run("/Workspace/Users/jayadheep356@gmail.com/DATABRICKS/src/Notebook_Calling/Notebook C", 60)

print("Result received from Notebook C:", result_from_c)

message = "Notebook B finished after calling C"

# Return result to Notebook A
dbutils.notebook.exit(message)
