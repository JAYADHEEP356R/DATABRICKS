# %%
# Notebook C

print("Notebook C started")

# Example pyspark logic
data = [("Apple", 10), ("Banana", 20), ("Orange", 30)]
df = spark.createDataFrame(data, ["Fruit", "Quantity"])

df.show()

result = "Notebook C completed successfully"

# Return result to Notebook B
dbutils.notebook.exit(result)
